# %%
import pandas as pd

# %%
# DataFrames are the workhorse datatype of the pandas library, a 2 dimensional iteratable table in which all the data from
# a CSV, excell, or other readable file type, can be organized and further inspected for cleaning, rearranging, or conducting
# analysis. The main way to make a dataframe you are likely to use is using the read_xxx() functions, which take the path
# to the file in question and interpret it into a dataframe. In the following example I am using a csv file that has the 
# food production statistics for a myriad of countries, regions, and continents over a 61 year period, obtained from kaggl
foodproduction = pd.read_csv("world-food-production.csv")
foodproduction
# Out:
#             Entity  Year  Maize Production (tonnes)  \
# 0      Afghanistan  1961                   700000.0
# 1      Afghanistan  1962                   700000.0
# 2      Afghanistan  1963                   713000.0
# 3      Afghanistan  1964                   720000.0
# 4      Afghanistan  1965                   720000.0
# ...            ...   ...                        ...
# 11907     Zimbabwe  2017                  1532572.0
# 11908     Zimbabwe  2018                  1560100.0
# 11909     Zimbabwe  2019                   773976.0
# 11910     Zimbabwe  2020                  1202347.0
# 11911     Zimbabwe  2021                  1469664.0
#
#        Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0                       319000.00               7.467702e+06
# 1                       319000.00               7.420515e+06
# 2                       319000.00               8.479074e+06
# 3                       380000.00               9.113779e+06
# ...
